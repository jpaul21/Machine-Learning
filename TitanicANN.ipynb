# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import csv
import os
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import recall_score 
from tensorflow import keras

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

np.random.seed(42)
tf.random.set_seed(42)

# Read and prepare file
data = pd.read_table('Titanic.csv', delimiter=',', header=0)
age_mean = data['age'].mean()
sibsp_mean = data['sibsp'].mean()
fare_mean = data['fare'].mean()
body_mean = data['body'].mean()

# Gender / Age / sibsp / pclass
data.age = data.age.fillna(value=age_mean)
data.sibsp = data.sibsp.fillna(value=sibsp_mean)
data.fare = data.fare.fillna(value=fare_mean)
data.body = data.body.fillna(value=body_mean)
data_adj = data.drop(['name', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], axis=1)
data_adj = data_adj.drop(data_adj.columns[0], axis=1)

# Convert strings to discrete values
le = preprocessing.LabelEncoder()
le.fit(data_adj['pclass'])
data_adj['pclass'] = le.transform(data['pclass'])
le.fit(data_adj['sex'])
data_adj['sex'] = le.transform(data_adj['sex'])

y = data_adj['survived']
x = data_adj.drop(['survived'], axis=1)
norm = MinMaxScaler().fit(x)
x_norm = norm.transform(x)

# Split Data 80:20 (Train:Test)
x_train, x_test, y_train, y_test = train_test_split(x_norm, y, test_size=0.2, random_state=42)

# %%
# Model 1
# units = nodes
# pclass, sex, age, sibsp
pclass_num = len(set(data_adj['pclass']))
sex_num = len(set(data_adj['sex']))
age_num = len(set(data_adj['age']))
sibsp_num = len(set(data_adj['sibsp']))
tot_nodes = pclass_num + sex_num + age_num + sibsp_num

model = tf.keras.Sequential()
model.add(tf.keras.layers.BatchNormalization())
model.add(keras.layers.Dense(tot_nodes,input_shape=x_train.shape[1:]))
model.add(keras.layers.Dense(tot_nodes, activation='sigmoid'))
model.add(keras.layers.Dense(50, activation='sigmoid'))
model.add(keras.layers.Dense(1, activation='sigmoid', input_shape=x_train.shape[1:]))

model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(x_train,y_train,batch_size=32,epochs = 50)
#model.summary()
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5).astype(int).ravel()
# accuracy(% survivors correctly predicted)  TP/(TP + FN)
mod1_surv = recall_score(y_test, y_pred, pos_label=1)

# accuracy(% fatalities correctly predicted)  TN/(TN + FP)
mod1_fat = recall_score(y_test, y_pred, pos_label=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 0s 549us/step - loss: 0.6901 - accuracy: 0.5435
# Epoch 2/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.6566 - accuracy: 0.6351
# Epoch 3/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6536 - accuracy: 0.6351
# Epoch 4/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6521 - accuracy: 0.6351
# Epoch 5/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6517 - accuracy: 0.6351
# Epoch 6/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6501 - accuracy: 0.6351
# Epoch 7/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.6493 - accuracy: 0.6351
# Epoch 8/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6478 - accuracy: 0.6351
# Epoch 9/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6467 - accuracy: 0.6351
# Epoch 10/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6450 - accuracy: 0.6351
# Epoch 11/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.6448 - accuracy: 0.6351
# Epoch 12/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.6431 - accuracy: 0.6351
# Epoch 13/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6425 - accuracy: 0.6351
# Epoch 14/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6407 - accuracy: 0.6351
# Epoch 15/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6391 - accuracy: 0.6351
# Epoch 16/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6379 - accuracy: 0.6351
# Epoch 17/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6370 - accuracy: 0.6351
# Epoch 18/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6350 - accuracy: 0.6351
# Epoch 19/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6345 - accuracy: 0.6351
# Epoch 20/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6327 - accuracy: 0.6351
# Epoch 21/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6305 - accuracy: 0.6351
# Epoch 22/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6291 - accuracy: 0.6351
# Epoch 23/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6268 - accuracy: 0.6351
# Epoch 24/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6250 - accuracy: 0.6351
# Epoch 25/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6237 - accuracy: 0.6351
# Epoch 26/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6218 - accuracy: 0.6351
# Epoch 27/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6194 - accuracy: 0.6351
# Epoch 28/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6174 - accuracy: 0.6351
# Epoch 29/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6155 - accuracy: 0.6351
# Epoch 30/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6130 - accuracy: 0.6351
# Epoch 31/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6093 - accuracy: 0.6351
# Epoch 32/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6083 - accuracy: 0.6361
# Epoch 33/50
# 33/33 [==============================] - 0s 688us/step - loss: 0.6038 - accuracy: 0.6351
# Epoch 34/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.6011 - accuracy: 0.6351
# Epoch 35/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5986 - accuracy: 0.6351
# Epoch 36/50
# 33/33 [==============================] - 0s 577us/step - loss: 0.5958 - accuracy: 0.6390
# Epoch 37/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5918 - accuracy: 0.6399
# Epoch 38/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5885 - accuracy: 0.6504
# Epoch 39/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5837 - accuracy: 0.6504
# Epoch 40/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.5811 - accuracy: 0.6619
# Epoch 41/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5764 - accuracy: 0.6581
# Epoch 42/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5737 - accuracy: 0.7011
# Epoch 43/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5718 - accuracy: 0.7230
# Epoch 44/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.5665 - accuracy: 0.7498
# Epoch 45/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.5649 - accuracy: 0.7326
# Epoch 46/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5570 - accuracy: 0.7660
# Epoch 47/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.5537 - accuracy: 0.7679
# Epoch 48/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5489 - accuracy: 0.7755
# Epoch 49/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5485 - accuracy: 0.7832
# Epoch 50/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.5395 - accuracy: 0.7813

# %%
# Model 2
model1 = tf.keras.Sequential()
model1.add(tf.keras.layers.BatchNormalization())
model1.add(keras.layers.Dense(tot_nodes,input_shape=x_train.shape[1:]))
model1.add(keras.layers.Dense(50, activation='sigmoid'))
model1.add(keras.layers.Dense(4, activation='sigmoid'))
model1.add(keras.layers.Dense(1, activation='sigmoid', input_shape=x_train.shape[1:]))


model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model1.fit(x_train,y_train,batch_size=32,epochs = 50)
#model.summary()
y_pred = model1.predict(x_test)
y_pred = (y_pred > 0.5).astype(int).ravel()
# accuracy(% survivors correctly predicted)  TP/(TP + FN)
mod2_surv = recall_score(y_test, y_pred, pos_label=1)

# accuracy(% fatalities correctly predicted)  TN/(TN + FP)
mod2_fat = recall_score(y_test, y_pred, pos_label=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.6324 - accuracy: 0.6351
# Epoch 2/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5751 - accuracy: 0.6781
# Epoch 3/50
# 33/33 [==============================] - 0s 531us/step - loss: 0.5367 - accuracy: 0.7956
# Epoch 4/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.5195 - accuracy: 0.7880
# Epoch 5/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.5170 - accuracy: 0.7870
# Epoch 6/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.5065 - accuracy: 0.7927
# Epoch 7/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.5082 - accuracy: 0.7851
# Epoch 8/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4983 - accuracy: 0.7994
# Epoch 9/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4959 - accuracy: 0.7975
# Epoch 10/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4972 - accuracy: 0.8032
# Epoch 11/50
# 33/33 [==============================] - 0s 625us/step - loss: 0.4944 - accuracy: 0.7947
# Epoch 12/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4919 - accuracy: 0.7956
# Epoch 13/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4917 - accuracy: 0.7966
# Epoch 14/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4894 - accuracy: 0.7947
# Epoch 15/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4826 - accuracy: 0.8052
# Epoch 16/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4880 - accuracy: 0.7947
# Epoch 17/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4848 - accuracy: 0.8052
# Epoch 18/50
# 33/33 [==============================] - 0s 629us/step - loss: 0.4867 - accuracy: 0.7899
# Epoch 19/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4871 - accuracy: 0.7927
# Epoch 20/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4823 - accuracy: 0.8004
# Epoch 21/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4750 - accuracy: 0.7966
# Epoch 22/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4751 - accuracy: 0.7985
# Epoch 23/50
# 33/33 [==============================] - 0s 625us/step - loss: 0.4724 - accuracy: 0.8042
# Epoch 24/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4690 - accuracy: 0.8128
# Epoch 25/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4683 - accuracy: 0.8052
# Epoch 26/50
# 33/33 [==============================] - 0s 625us/step - loss: 0.4655 - accuracy: 0.8166
# Epoch 27/50
# 33/33 [==============================] - 0s 625us/step - loss: 0.4658 - accuracy: 0.8061
# Epoch 28/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4621 - accuracy: 0.8042
# Epoch 29/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4629 - accuracy: 0.8023
# Epoch 30/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4578 - accuracy: 0.8099
# Epoch 31/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4560 - accuracy: 0.8042
# Epoch 32/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4580 - accuracy: 0.8023
# Epoch 33/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4534 - accuracy: 0.8099
# Epoch 34/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4537 - accuracy: 0.8109
# Epoch 35/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4555 - accuracy: 0.8090
# Epoch 36/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4517 - accuracy: 0.8013
# Epoch 37/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4501 - accuracy: 0.8118
# Epoch 38/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4503 - accuracy: 0.8042
# Epoch 39/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4445 - accuracy: 0.8099
# Epoch 40/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4498 - accuracy: 0.8061
# Epoch 41/50
# 33/33 [==============================] - 0s 625us/step - loss: 0.4436 - accuracy: 0.8071
# Epoch 42/50
# 33/33 [==============================] - 0s 564us/step - loss: 0.4489 - accuracy: 0.8080
# Epoch 43/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4485 - accuracy: 0.8080
# Epoch 44/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4463 - accuracy: 0.8071
# Epoch 45/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4497 - accuracy: 0.8109
# Epoch 46/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4443 - accuracy: 0.8118
# Epoch 47/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4433 - accuracy: 0.8109
# Epoch 48/50
# 33/33 [==============================] - 0s 563us/step - loss: 0.4420 - accuracy: 0.8090
# Epoch 49/50
# 33/33 [==============================] - 0s 594us/step - loss: 0.4423 - accuracy: 0.8090
# Epoch 50/50
# 33/33 [==============================] - 0s 625us/step - loss: 0.4387 - accuracy: 0.8157

# %%
from sklearn.ensemble import RandomForestClassifier
from tabulate import tabulate

rnd_clf = RandomForestClassifier(n_estimators=50, max_leaf_nodes=40, n_jobs=-1)
rnd_clf.fit(x_train, y_train)
y_pred_rf = rnd_clf.predict(x_test)

# accuracy(% survivors correctly predicted)   TP/(TP + FN)
random_forest_surv = recall_score(y_test, y_pred_rf, pos_label=1)

# accuracy(% fatalities correctly predicted)   TN/(TN + FP)
random_forest_fat = recall_score(y_test, y_pred_rf, pos_label=0)

table = [['Learning Model', 'Accuracy Survivors Correctly Predicted', 'Accuracy Fatalities Correctly Predicted'],
        ['Model #1', mod1_surv, mod1_fat],
        ['Model #2', mod2_surv, mod2_fat],
        ['Random Forest', random_forest_surv, random_forest_fat]]

print(tabulate(table, headers='firstrow'))
# Out:
# Learning Model      Accuracy Survivors Correctly Predicted    Accuracy Fatalities Correctly Predicted
# ----------------  ----------------------------------------  -----------------------------------------
# Model #1                                          0.627119                                   0.875
# Model #2                                          0.550847                                   0.923611
# Random Forest                                     0.576271                                   0.895833
